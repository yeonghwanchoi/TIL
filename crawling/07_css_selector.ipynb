# %% [markdown]
# ### CSS Selector
# - HTML 엘리먼트에 CSS 스타일을 적용실때 엘리먼트를 선택하기위한 방법
# - 선택하는 방법
#     - tag 이름
#     - id 값
#     - class 값
#     - attribute 값

# %% [markdown]
# #### 1. 태그 이름으로 선택
# - data 1 엘리먼트를 선택
# - css-selector : `div`

# %% [markdown]
# #### 2. 아이디 값으로 선택
# - data 2를 아이디 값으로 선택
# - css-selector : `#txt`

# %% [markdown]
# #### 3. 클래스 값으로 선택
# - data 3를 클래스 값으로 선택
# - css-selector : `.no2`
# - `.dss-txt` : data 2, data 3 가 선택

# %% [markdown]
# #### 4. 속성값으로 선택
# - data 4를 속성 값으로 선택
# - css-selector : `[val="d4"]`, `[id="da4"]`

# %% [markdown]
# #### 5. 혼합해서 사용
# - span 태그, class 값이 no5 엘리먼트를 선택
# - css-selector : `span.no5`

# %%
# %%html
# <div id="wrap" class="dss">data 1</div>
# <p id="txt" class="dss-txt no1">data 2</p>
# <span class="dss-txt no2" val="d3">data 3</span>
# <span id="da4" val="d4">data 4</span>
# <span class="no5">data 5</span>
# Out:
# <div id="wrap" class="dss">data 1</div>
# <p id="txt" class="dss-txt no1">data 2</p>
# <span class="dss-txt no2" val="d3">data 3</span>
# <span id="da4" val="d4">data 4</span>
# <span class="no5">data 5</span>

# %% [markdown]
# #### 6. not selector
# - 선택된 엘리먼트에서 특정 조건의 엘리먼트를 제거해서 선택
# - data 2 엘리먼트만 제외한 ds 클래스를 선택
# - css-selector : `.ds:not(.dss2)`

# %% [markdown]
# #### 7. nth-child
# - n 번째의 엘리먼트를 선택
# - data 3 선택하는 방법
# - css-selector : `.ds:nth-child(3)`
# - `<span>data 0</span>` 가 추가되면 data 2를 선택

# %%
# %%html
# <div>
#     <span>data 0</span>
#     <p class="ds dss1">data 1</p>
#     <p class="ds dss2">data 2</p>
#     <p class="ds dss3">data 3</p>
#     <p class="ds dss4">data 4</p>
#     <div class="wrap">
#         <p class="ds dss1">data 1</p>
#         <p class="ds dss2">data 2</p>
#         <p class="ds dss3">data 3</p>
#         <p class="ds dss4">data 4</p>
#     </div>
# </div>
# <div></div>
# <div class="ds">data 5</div>
# Out:
# <div>
#     <span>data 0</span>
#     <p class="ds dss1">data 1</p>
#     <p class="ds dss2">data 2</p>
#     <p class="ds dss3">data 3</p>
#     <p class="ds dss4">data 4</p>
#     <div>
#         <p class="ds dss1">data 1</p>
#         <p class="ds dss2">data 2</p>
#         <p class="ds dss3">data 3</p>
#         <p class="ds dss4">data 4</p>
#     </div>
# </div>
# <div></div>
# <div class="ds">data 5</div>

# %% [markdown]
# #네이버 키워드 데이터 가져오기 html 데이터 파싱
#
# 웹페이지 분석 :url 찾기
# 요청 ->응답 : html(str)
# html(str) - beautifulsoup obj (css selector)-> DF

# %%
#1웹페이지 분석
query="삼성전자"
url="https://search.naver.com/search.naver?sm=top_hty&fbm=0\
&ie=utf8&query={}".format(query)
print(url)
# Out:
# https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=삼성전자

# %%
# request -> response:html(str)
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="삼성전자 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'삼성전자\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'삼성전자\'의 네이버 통합검색 결과입니다."> <title>삼성전자 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200528.css"> <link rel="stylesheet" type="text/css
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
#HTML(str)-> Beautifulsoup obj (css-selecter)->데이터프레임
dom=BeautifulSoup(response.content, 'html.parser')
type(dom)
dom
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
#dom 가장많이 사용하는 함수 2개
#select : 여러게의 엘리먼트 객체를 리스트로 가져옴
#select_one : 하나의 엘리먼트 객체를 가져옴

# %%
elements = dom.select("._related_keyword_ul > li")
len(elements)
# Out:
# 10

# %%
elements[0]
# Out:
# <li> <a data-area="*q" data-idx="1" href="?where=nexearch&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90%EC%9A%B0&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">삼성전자우</a> </li>

# %%
type(elements[0])
# Out:
# bs4.element.Tag

# %%
keywords = []
for element in elements:
    keywords.append(element.text.strip())
print(keywords)
# Out:
# ['삼성전자우', '카카오', '삼성', '네이버', 'sk하이닉스', '셀트리온', '삼성중공업우', '코스피', '삼성전자서비스센터', '삼성sdi']

# %%
keywords = [ element.text.strip() for element in elements ]

# %%
#함수로 만들기
def naver_relational_keywords(query):
    url="https://search.naver.com/search.naver?sm=top_hty&fbm=0\
&ie=utf8&query={}".format(query)
    response = requests.get(url)
    dom=BeautifulSoup(response.content, 'html.parser')
    elements = dom.select("._related_keyword_ul > li")
    return [element.text.strip() for element in elements]

# %%
query="유나"
result=naver_relational_keywords(query)
# Out:
# []

# %%
###다음 뉴스에 메인 페이지 15개 시가의 제목, 링크, 내용 수집
url="https://news.daum.net/"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
dom = BeautifulSoup(response.content,"html.parser")
dom
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0 " lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/fb62e64/common.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/fb62e64/news.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/fb62e64/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
elements = dom.select(".list_headline > li")
elements
# Out:
# [<li class="item_main">
#  <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20200625142619272" data-tiara-id="20200625142619272" data-tiara-layer="photo" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20200625142619272">
#  <span class="wrap_thumb">
#  <img '햄버거병'="" alt="안산 유치원 식중독 99명으로 늘어.." class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202006%2F25%2Fyonhap%2F20200625142619518mtbz.jpg&amp;scode=media" 일부="" 추정""=""/>
#  </span>
#  <strong class="tit_g">안산 유치원 식중독 99명으로 늘어.."일부 '햄버거병' 추정"</strong>
#  </a>
#  </li>,
#  <li>
#  <strong class="tit_g">
#  <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20200625141154622" data-tiara-id="20200625141154622" data-tiara-layer="article" data-tiara-ordnum="5" data-tiara-type="harmony" href="https://news.v.daum.net/v/20200625141154622">코로나19 이후 귀농·귀촌 인구는 늘어들까? 줄어들까?</a>
#  <span class="info_news">KBS</span>
#  </strong>
# ...

# %%
len(elements)
# Out:
# 15

# %%
elements[0]
# Out:
# <li class="item_main">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20200625142619272" data-tiara-id="20200625142619272" data-tiara-layer="photo" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20200625142619272">
# <span class="wrap_thumb">
# <img '햄버거병'="" alt="안산 유치원 식중독 99명으로 늘어.." class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202006%2F25%2Fyonhap%2F20200625142619518mtbz.jpg&amp;scode=media" 일부="" 추정""=""/>
# </span>
# <strong class="tit_g">안산 유치원 식중독 99명으로 늘어.."일부 '햄버거병' 추정"</strong>
# </a>
# </li>

# %%
#
datas=[]
for element in elements:
    datas.append({
        "title":element.select_one('.tit_g').text.strip().replace("\n",""),
        "link":element.select_one("a").get("href")
    })

# %%
articles_df = pd.DataFrame(datas)
articles_df.tail(2)
# Out:
#                                     title  \
# 13  '기밀 유출 온상' 국방과학연구소, 퇴직자 취업제한 기준 허술뉴시스
# 14     6·17대책 효과 아직?..수도권 아파트값 상승폭 커져연합뉴스
#
#                                            link
# 13  https://news.v.daum.net/v/20200625140015084
# 14  https://news.v.daum.net/v/20200625140009064

# %%
articles_df.loc[0,"link"]
# Out:
# 'https://news.v.daum.net/v/20200625142619272'

# %%
link=articles_df.loc[0,"link"]
print(link)
# Out:
# https://news.v.daum.net/v/20200625142619272

# %%
response = requests.get(link)
dom = BeautifulSoup(response.content, "html.parser")

# %%
content=dom.select_one("#harmonyContainer").text.strip().replace("\n","")

# %%
def get_content(link):
    response = requests.get(link)
    dom = BeautifulSoup(response.content, "html.parser")
    return dom.select_one("#harmonyContainer").text.strip().replace("\n","")

# %%
articles_df["contents"]=articles_df["link"].apply(get_content)

# %%
articles_df.tail()
# Out:
#                                      title  \
# 10     집단감염 러시아 선박 접촉자 152명 '음성'..11명 검사 중
# 11  캘리포니아 주지사 6·25 70주년 메시지 "절대 잊지 말자"연합뉴스
# 12  코로나발 대출 연체에 안전망.."캠코에 채권 매입 요청하세요"연합뉴스
# 13   '기밀 유출 온상' 국방과학연구소, 퇴직자 취업제한 기준 허술뉴시스
# 14      6·17대책 효과 아직?..수도권 아파트값 상승폭 커져연합뉴스
#
#                                            link  \
# 10  https://news.v.daum.net/v/20200625142126081
# 11  https://news.v.daum.net/v/20200625140041116
# 12  https://news.v.daum.net/v/20200625140017087
# 13  https://news.v.daum.net/v/20200625140015084
# 14  https://news.v.daum.net/v/20200625140009064
#
#                                              contents
# 10  23일 오후 부산 감천항에 정박한 러시아 국적 냉동화물선에서 코로나19 양성 판정을...
# 11  개빈 뉴섬 캘리포니아 주지사 [AP=연합뉴스 자료사진]           (로스앤젤...
# 12  (서울=연합뉴스) 김남권 김다혜 기자 = 이달 29일부터 신종 코로나바이러스 감염증...
# 13  【서울=뉴시스】국방과학연구소(ADD) 창조관. (사진=뉴시스DB)          ...
# 14  (서울=연합뉴스) 김동규 기자 = 서울·경기·인천 등 수도권 아파트값이 6·17 부...
