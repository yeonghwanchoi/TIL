# %%
# Out:
#   File "<ipython-input-4-a479fd4432f1>", line 1
#     $ sudo apt-get install -y fonts-nanum*
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib as mpl
import matplotlib.pylab as plt
# %matplotlib inline

# %%
#line plot
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()
